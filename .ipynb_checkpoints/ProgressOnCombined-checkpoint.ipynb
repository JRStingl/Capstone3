# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import pairwise_distances, pairwise_distances_chunked
from scipy.sparse import vstack
from nltk.corpus.reader.wordnet import NOUN
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
total = pd.read_csv("Combined_Netflix_IMDb_Useful_Columns.csv", low_memory=False)

# %%
total.fillna("NAN",inplace=True)

# %%
total.drop('Unnamed: 0', axis=1, inplace=True)

# %%
def remove_spaces(lst):
    spaces_removed = []
    for name in lst:
        spaces_removed.append(name.replace(" ", ""))
    return spaces_removed

# %%
def list_for_remove(string):
    string=str(string)
    return " ".join(remove_spaces(string.split(", ")))

# %%
def clean_up(pd_df):
    #fill any NAN values
    pd_df =pd_df.copy()
    #remove spaces from actors and directors names
    pd_df.actors = pd_df.actors.apply(lambda x: list_for_remove(x))
    pd_df.director = pd_df.director.apply(lambda x: list_for_remove(x))
    pd_df.genre = pd_df.genre.apply(lambda x: list_for_remove(x))
    return pd_df

# %%
total = clean_up(total)

# %%
def get_keywords(pd_df):
    pd_df = pd_df.copy()
    pd_df.description = pd_df.description.apply(lambda x: make_keywords(x, dis=True))
    pd_df.original_title = pd_df.original_title.apply(lambda x: make_keywords(x))
    return pd_df

# %%
def make_keywords(string,dis=False):
#     if dis:
#         string=translated.translate(string)
    tokens = word_tokenize(string)
    # convert to lower case
    tokens = [w.lower() for w in tokens]
    # remove punctuation from each word
    import string
    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    words = [word for word in stripped if word.isalpha()]
    # filter out stop words
    from nltk.corpus import stopwords
    stop_words = set(stopwords.words('english'))
    if not dis:
        stop_words = set(stopwords.words(['arabic', 'azerbaijani', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek','hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']))
    words = [w for w in words if not w in stop_words]
    lem = WordNetLemmatizer()
    words = [lem.lemmatize(w) for w in words]
    return " ".join(words)

# %%
total = get_keywords(total)

# %%
total.to_csv('translated_in_case.csv')

# %%
total = pd.read_csv('in_case.csv', low_memory=False)

# %%
total.drop('Unnamed: 0', axis=1, inplace=True)

# %%
def mashup(pd_df):
    str_list = []
    key = ''
    direct = ' '
    act = ' '
    descrip = ' '
    for i in range(pd_df.shape[0]):
        if i not in pd_df.index:
            continue
        if pd_df.description[i] != 'NAN':
            descrip = pd_df.description[i] + " "
        if pd_df.actors[i] != 'NAN':
            act = (pd_df.actors[i] + " ") * 5
        if pd_df.director[i] != 'NAN':
            direct = (pd_df.director[i] + " ") * 10
        
        key = direct + " " + act + " " + descrip + " " + ((pd_df.original_title[i] + " ")*5) + pd_df.genre[i] + " " + pd_df.year[i]
        str_list.append(key)
    return str_list

# %%
def mashup(pd_df):
    str_list = []
    key = ''
    direct = ' '
    act = ' '
    descrip = ' '
    for i in range(pd_df.shape[0]):
        if i not in pd_df.index:
            continue
        if pd_df.description[i] != 'NAN':
            descrip = pd_df.description[i] + " "
        if pd_df.actors[i] != 'NAN':
            act = (pd_df.actors[i] + " ") * 5
        if pd_df.director[i] != 'NAN':
            direct = (pd_df.director[i] + " ") * 7
        
        key = direct + " " + act + " " + descrip + " " + ((pd_df.original_title[i] + " ")*3) + ((pd_df.genre[i] + " ")*2) + pd_df.year[i]
        str_list.append(key)
    return str_list

# %%
total_lst = mashup(total)

# %%
total = total.fillna("NAN")

# %%
total
# Out:
#         title_id     type               original_title  \
# 0      tt0000009    Movie                   miss jerry
# 1      tt0000574    Movie             story kelly gang
# 2      tt0001892    Movie                   sorte drøm
# 3      tt0002101    Movie                    cleopatra
# 4      tt0002130    Movie                     linferno
# ...          ...      ...                          ...
# 93637      s7783    Movie                         zozo
# 93638      s7784    Movie                       zubaan
# 93639      s7785    Movie                   zulu japan
# 93640      s7786  TV Show                zumbo dessert
# 93641      s7787    Movie  zz top little ol band texas
#
#                                director  \
# 0                        AlexanderBlack
# 1                           CharlesTait
# 2                              UrbanGad
# 3                      CharlesL.Gaskill
# 4      FrancescoBertolini AdolfoPadovan
# ...                                 ...
# 93637                        JosefFares
# 93638                        MozezSingh
# 93639                               NAN
# 93640                               NAN
# 93641                           SamDunn
#
#                                                   actors  year  duration  \
# 0          BlancheBayliss WilliamCourtenay ChaunceyDepew  1894        45
# 1      ElizabethTait JohnTait NormanCampbell BellaCol...  1906        70
# 2      AstaNielsen ValdemarPsilander GunnarHelsengree...  1911        53
# 3      HelenGardner PearlSindelar MissFielding MissRo...  1912       100
# 4      SalvatorePapa ArturoPirovano GiuseppedeLiguoro...  1911        68
# ...                                                  ...   ...       ...
# 93637  ImadCreidi AntoinetteTurk EliasGergi CarmenLeb...  2005        99
# 93638  VickyKaushal Sarah-JaneDias RaaghavChanana Man...  2015       111
# 93639                                             NastyC  2019        44
# 93640                            AdrianoZumbo RachelKhoo  2019  1 Season
# 93641                                                NAN  2019        90
#
#                                                   genre  \
# 0                                               Romance
# 1                                 Biography Crime Drama
# 2                                                 Drama
# 3                                         Drama History
# 4                               Adventure Drama Fantasy
# ...                                                 ...
# 93637                        Dramas InternationalMovies
# 93638         Dramas InternationalMovies Music&Musicals
# 93639  Documentaries InternationalMovies Music&Musicals
# 93640                    InternationalTVShows RealityTV
# 93641                      Documentaries Music&Musicals
#
#                                              description
# 0                              adventure female reporter
# 1       true story notorious australian outlaw ned kelly
# 2      two men high rank wooing beautiful famous eque...
# 3      fabled queen egypt affair roman general marc a...
# 4      loosely adapted dante divine comedy inspired i...
# ...                                                  ...
# 93637  lebanon civil war deprives zozo family left gr...
# 93638  scrappy poor boy worm way tycoon dysfunctional...
# 93639  documentary south african rapper nasty c hit s...
# 93640  dessert wizard adriano zumbo look next willy w...
# 93641  documentary delf mystique behind bluesrock tri...
#
# [93642 rows x 9 columns]

# %%
# (total.actors[i]+" ")*5

# %% [markdown]
# The Following Cells were for getting the total title list don't run again.

# %%
# for_list = pd.read_csv("Combined_Netflix_IMDb_Useful_Columns.csv", low_memory=False)

# %%
# title_list = for_list.original_title.to_list()

# %%
# for k, v in enumerate(title_list):
#     title_list[k] = v + " ("+for_list.year.iloc[k]+")"

# %%
# dbfile = open(f'all_title_list.pkl', 'ab')
# # source, destination
# pickle.dump(title_list, dbfile)                     
# dbfile.close()

# %%
# dbfile = open(f'all_title_list.pkl', 'rb')
# # source, destination
# title = pickle.load(dbfile)                     
# dbfile.close()

# %%
vectorizor = CountVectorizer()
keys = vectorizor.fit_transform(total_lst)

# %%
dist = pairwise_distances_chunked(keys, metric='cosine')

# %%
y=0
while (y < total.shape[0]):
    pull = next(dist)
    if y == 0:
        save = pull.shape[0]
    y += pull.shape[0]
    dbfile = open(f'distance/translated_weights_full_set{y}.pkl', 'ab')
    # source, destination
    pickle.dump(pull, dbfile)                     
    dbfile.close()
save
# Out:
# 1433

# %%
dbfile = open(f'offset.pkl', 'ab')
# source, destination
pickle.dump(save, dbfile)                     
dbfile.close()

# %%
lst = []
for val in total.duration:
    if len(val)<4:
        lst.append(int(val))
min(lst)
# Out:
# 3

# %%
total[total.duration=='3']
# Out:
#       title_id   type original_title                        director actors  \
# 91460    s5606  Movie         silent  LimbertFabian BrandonOldenburg    NAN
#
#        year duration                                 genre  \
# 91460  2014        3  Children&FamilyMovies Sci-Fi&Fantasy
#
#                                              description
# 91460  silent animated short film created academy win...

# %%
from deep_translator import GoogleTranslator

# %%
translated = GoogleTranslator(source='auto', target='en')

# %%
translated.translate("Hola, mi amour")
# Out:
# 'Hello my love'

# %%
total.description = total.description.apply(lambda x: translated.translate(x))

# %%
total.to_csv("translated_hopefully.csv")

# %%
total[total.original_title.str.contains(" Z ")]
# Out:
#         title_id   type                                     original_title  \
# 7178   tt0044563  Movie                               Down Among the Z Men
# 46635  tt0435202  Movie          Kidô senshi Z Gandamu: Hoshi o tsugu mono
# 48093  tt0468812  Movie            Kidô senshi Z Gandamu II: Koibito tachi
# 48991  tt0488584  Movie     Kidô senshi Z Gandamu III: Hoshi no kodô wa ai
# 65850  tt2263944  Movie       Dragon Ball Z: Doragon bôru Z - Kami to Kami
# 68244  tt2657152  Movie                                      War Z Day One
# 72376  tt3718066  Movie                Captain Z & the Terror of Leviathan
# 72755  tt3819668  Movie    Dragon Ball Z: Doragon bôru Z - Fukkatsu no 'F'
# 78202  tt5625152  Movie                                       Pojdi Z Mano
# 78985  tt5889204  Movie  Pokemon za mubi XY& Z 'borukenion to kiko (kar...
#
#                  director                                             actors  \
# 7178       Maclean Rogers  Harry Secombe, Michael Bentine, Spike Milligan...
# 46635    Yoshiyuki Tomino  Toshio Furukawa, Tôru Furuya, Kazuhiko Inoue, ...
# 48093    Yoshiyuki Tomino  Tôru Furuya, Marika Hayashi, Shûichi Ikeda, Ch...
# 48991    Yoshiyuki Tomino  Nobuo Tobita, Shûichi Ikeda, Yoshiko Sakakibar...
# 65850     Masahiro Hosoda  Masako Nozawa, Hiromi Tsuru, Ryô Horikawa, Mas...
# 68244          Lana Titov  Josh Butcher, Annakate Chappell, Mark Conlon, ...
# 72376     Steve Rudzinski  Zoltan Zilai, Madison Siple, Steve Rudzinski, ...
# 72755  Tadayoshi Yamamuro  Masako Nozawa, Ryô Horikawa, Hiromi Tsuru, Mas...
# 78202          Igor Sterk  Ivan Vastl, Mak Tepsic, Ronja Matijevec Jerman...
# 78985     Kunihiko Yuyama  Tyler Bunch, James Carter Cathcart, Daniel J. ...
#
#        year duration                         genre  \
# 7178   1952       71                        Comedy
# 46635  2004       94      Animation, Action, Drama
# 48093  2005       98      Animation, Action, Drama
# 48991  2006       99      Animation, Action, Drama
# 65850  2013       85  Animation, Action, Adventure
# 68244  2013       58      Horror, Sci-Fi, Thriller
# 72376  2014       80                        Comedy
# 72755  2015       93  Animation, Action, Adventure
# 78202  2016       83  Adventure, Mystery, Thriller
# 78985  2016       90  Animation, Action, Adventure
#
#                                              description
# 7178   The cast of the popular radio program "The Goo...
# 46635  10 years after the One Year War Camille Bidan ...
# 48093  Camille falls in love with the unstable enemy ...
# 48991                                                NAN
# 65850  The Z-Fighters must contend with Lord Beerus, ...
# 68244  Peter is obsessed with apocalypses. He reads a...
# 72376  In 1714 Captain Zachariah Zicari stops a group...
# 72755  One peaceful day on Earth, two remnants of Fre...
# 78202  In search of the best photo for the school com...
# 78985  A mystical Pokémon by the name of Volcanion mu...

# %%
test = pd.read_csv("Combined_Netflix_IMDb_Useful_Columns.csv", low_memory=False)

# %%
test[test.title_id=='tt3819668']
# Out:
#        Unnamed: 0   title_id   type  \
# 72755       72755  tt3819668  Movie
#
#                                         original_title            director  \
# 72755  Dragon Ball Z: Doragon bôru Z - Fukkatsu no 'F'  Tadayoshi Yamamuro
#
#                                                   actors  year duration  \
# 72755  Masako Nozawa, Ryô Horikawa, Hiromi Tsuru, Mas...  2015       93
#
#                               genre  \
# 72755  Animation, Action, Adventure
#
#                                              description
# 72755  One peaceful day on Earth, two remnants of Fre...

# %%
total
# Out:
#         title_id     type                           original_title  \
# 0      tt0000009    Movie                               Miss Jerry
# 1      tt0000574    Movie              The Story of the Kelly Gang
# 2      tt0001892    Movie                           Den sorte drøm
# 3      tt0002101    Movie                                Cleopatra
# 4      tt0002130    Movie                                L'Inferno
# ...          ...      ...                                      ...
# 93637      s7783    Movie                                     Zozo
# 93638      s7784    Movie                                   Zubaan
# 93639      s7785    Movie                        Zulu Man in Japan
# 93640      s7786  TV Show                    Zumbo's Just Desserts
# 93641      s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                   director  \
# 0                          Alexander Black
# 1                             Charles Tait
# 2                                Urban Gad
# 3                       Charles L. Gaskill
# 4      Francesco Bertolini, Adolfo Padovan
# ...                                    ...
# 93637                          Josef Fares
# 93638                          Mozez Singh
# 93639                                  NAN
# 93640                                  NAN
# 93641                             Sam Dunn
#
#                                                   actors  year  duration  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...  1894        45
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...  1906        70
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...  1911        53
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...  1912       100
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...  1911        68
# ...                                                  ...   ...       ...
# 93637  Imad Creidi, Antoinette Turk, Elias Gergi, Car...  2005        99
# 93638  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...  2015       111
# 93639                                            Nasty C  2019        44
# 93640                         Adriano Zumbo, Rachel Khoo  2019  1 Season
# 93641                                                NAN  2019        90
#
#                                                    genre  \
# 0                                                Romance
# 1                                Biography, Crime, Drama
# 2                                                  Drama
# 3                                         Drama, History
# 4                              Adventure, Drama, Fantasy
# ...                                                  ...
# 93637                       Dramas, International Movies
# 93638     Dramas, International Movies, Music & Musicals
# 93639  Documentaries, International Movies, Music & M...
# 93640                 International TV Shows, Reality TV
# 93641                    Documentaries, Music & Musicals
#
#                                              description
# 0      The adventures of a female reporter in the 1890s.
# 1      True story of notorious Australian outlaw Ned ...
# 2      Two men of high rank are both wooing the beaut...
# 3      The fabled queen of Egypt's affair with Roman ...
# 4      Loosely adapted from Dante's Divine Comedy and...
# ...                                                  ...
# 93637  When Lebanon's Civil War deprives Zozo of his ...
# 93638  A scrappy but poor boy worms his way into a ty...
# 93639  In this documentary, South African rapper Nast...
# 93640  Dessert wizard Adriano Zumbo looks for the nex...
# 93641  This documentary delves into the mystique behi...
#
# [93642 rows x 9 columns]

# %%
top_ten = total.iloc[recommends][(total.iloc[recommends].genre.str.contains(genre))].original_title[0:3].values

# %%
recommends=[0,23,86732]

# %%
test[total.title_id == 's4826']
# Out:
#        Unnamed: 0 title_id   type          original_title  director actors  \
# 90680       90680    s4826  Movie  Perú: Tesoro escondido  Luis Ara    NaN
#
#        year duration                                genre  \
# 90680  2017       76  Documentaries, International Movies
#
#                                              description
# 90680  It's a country steeped in cultural traditions ...

# %%
genre = ''

# %%
ids = total.iloc[recommends][(total.iloc[recommends].genre.str.contains(genre))].title_id[0:3].values

# %%
    new_ids=[]
    for m_id, title in zip(ids,top_ten):
        if m_id[0]=='s':
            # _, imdb_id = get_imdb_link(imdb_movies[imdb_movies.title_id==id].original_title)
            print(m_id, title)
            _, imdb_id = get_imdb_link(title)
            new_ids.append(imdb_id)
        else:
            new_ids.append(m_id)
    ids = new_ids
# Out:
# s878 Beyond the Boundary: ICC Women's T20 World Cup Australia 2020

# %%
from urllib.parse import urlencode, urlparse, parse_qs
from lxml.html import fromstring
from requests import get
import time

# %%
def get_imdb_link(x):
    if x[0]=='t':
        return x
    title = total[total.title_id==x].original_title.values[0]
    title = "+".join(title.split())
    title = title + "+" + (total[total.title_id==x].type) + "+" + (total[total.title_id==x].year)
    raw = get(f"https://www.google.com/search?q=imdb+{title}").text
#     print(title, lst[1].split('/')[0])
    lst = raw.split("https://www.imdb.com/title/")
    link = "https://www.imdb.com/title/" + lst[1].split('/')[0]
    print(title, lst[1].split('/')[0])
    time.sleep(5)
    return lst[1].split('/')[0]

# %%
86732
# Out:
# 86732

# %%
total
# Out:
#         title_id     type                           original_title  \
# 0      tt0000009    Movie                               Miss Jerry
# 1      tt0000574    Movie              The Story of the Kelly Gang
# 2      tt0001892    Movie                           Den sorte drøm
# 3      tt0002101    Movie                                Cleopatra
# 4      tt0002130    Movie                                L'Inferno
# ...          ...      ...                                      ...
# 93637      s7783    Movie                                     Zozo
# 93638      s7784    Movie                                   Zubaan
# 93639      s7785    Movie                        Zulu Man in Japan
# 93640      s7786  TV Show                    Zumbo's Just Desserts
# 93641      s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                   director  \
# 0                          Alexander Black
# 1                             Charles Tait
# 2                                Urban Gad
# 3                       Charles L. Gaskill
# 4      Francesco Bertolini, Adolfo Padovan
# ...                                    ...
# 93637                          Josef Fares
# 93638                          Mozez Singh
# 93639                                  NAN
# 93640                                  NAN
# 93641                             Sam Dunn
#
#                                                   actors  year  duration  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...  1894        45
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...  1906        70
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...  1911        53
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...  1912       100
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...  1911        68
# ...                                                  ...   ...       ...
# 93637  Imad Creidi, Antoinette Turk, Elias Gergi, Car...  2005        99
# 93638  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...  2015       111
# 93639                                            Nasty C  2019        44
# 93640                         Adriano Zumbo, Rachel Khoo  2019  1 Season
# 93641                                                NAN  2019        90
#
#                                                    genre  \
# 0                                                Romance
# 1                                Biography, Crime, Drama
# 2                                                  Drama
# 3                                         Drama, History
# 4                              Adventure, Drama, Fantasy
# ...                                                  ...
# 93637                       Dramas, International Movies
# 93638     Dramas, International Movies, Music & Musicals
# 93639  Documentaries, International Movies, Music & M...
# 93640                 International TV Shows, Reality TV
# 93641                    Documentaries, Music & Musicals
#
#                                              description
# 0      The adventures of a female reporter in the 1890s.
# 1      True story of notorious Australian outlaw Ned ...
# 2      Two men of high rank are both wooing the beaut...
# 3      The fabled queen of Egypt's affair with Roman ...
# 4      Loosely adapted from Dante's Divine Comedy and...
# ...                                                  ...
# 93637  When Lebanon's Civil War deprives Zozo of his ...
# 93638  A scrappy but poor boy worms his way into a ty...
# 93639  In this documentary, South African rapper Nast...
# 93640  Dessert wizard Adriano Zumbo looks for the nex...
# 93641  This documentary delves into the mystique behi...
#
# [93642 rows x 9 columns]

# %%
total.title_id = total.title_id.apply(lambda x: get_imdb_link(x))
# Out:
# 85855    3%+TV Show+2020
# dtype: object
# 85856    7:19+Movie+2016
# dtype: object
# 85857    23:59+Movie+2011
# dtype: object
# 85858    9+Movie+2009
# dtype: object
# 85859    21+Movie+2008
# dtype: object
# 85860    46+TV Show+2016
# dtype: object
# 85861    122+Movie+2019
# dtype: object
# 85862    187+Movie+1997
# dtype: object
# 85863    706+Movie+2019
# dtype: object
# 85864    1920+Movie+2008
# dtype: object
# 85865    1922+Movie+2017
# dtype: object
# 85866    1983+TV Show+2018
# dtype: object
# 85867    1994+TV Show+2019
# dtype: object
# 85868    2,215+Movie+2018
# dtype: object
# 85869    3022+Movie+2019
# dtype: object
# 85870    Oct-01+Movie+2014
# dtype: object
# 85871    Feb-09+TV Show+2018
# dtype: object
# 85872    22-Jul+Movie+2018
# dtype: object
# 85873    15-Aug+Movie+2019
# dtype: object
# 85874    '89+Movie+2017
# dtype: object
# 85875    ​​Kuch+Bheege+Alfaaz+Movie+2018
# dtype: object
# 85876    ​Goli+Soda+2+Movie+2018
# dtype: object
# 85877    ​Maj+Rati+​​Keteki+Movie+2017
# dtype: object
# 85878    ​Mayurakshi+Movie+2017
# dtype: object
# 85879    ​SAINT+SEIYA:+Knights+of+the+Zodiac+TV Show+2020
# dtype: object
# 85880    (T)ERROR+Movie+2015
# dtype: object
# 85881    (Un)Well+TV Show+2020
# dtype: object
# 85882    #Alive+Movie+2020
# dtype: object
# 85883    #AnneFrank+-+Parallel+Stories+Movie+2019
# dtype: object
# 85884    #blackAF+TV Show+2020
# dtype: object
# 85885    #cats_the_mewvie+Movie+2020
# dtype: object
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-2cd9878a19c9> in <module>
# ----> 1 total.title_id = total.title_id.apply(lambda x: get_imdb_link(x))
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-9-2cd9878a19c9> in <lambda>(x)
# ----> 1 total.title_id = total.title_id.apply(lambda x: get_imdb_link(x))
#
# <ipython-input-8-5ad55e85eb67> in get_imdb_link(x)
#       8     print(title)
#       9     lst = raw.split("https://www.imdb.com/title/")
# ---> 10     link = "https://www.imdb.com/title/" + lst[1].split('/')[0]
#      11     time.sleep(5)
#      12     return lst[1].split('/')[0]
#
# IndexError: list index out of range

# %%
 total[total.title_id=='s878'].original_title.values[0]
# Out:
# "Beyond the Boundary: ICC Women's T20 World Cup Australia 2020"

# %%
total.iloc[85855]
# Out:
# Unnamed: 0                                                    85855
# title_id                                                         s1
# type                                                        TV Show
# original_title                                                   3%
# director                                                        NAN
# actors            João Miguel, Bianca Comparato, Michel Gomes, R...
# year                                                           2020
# duration                                                  4 Seasons
# genre             International TV Shows, TV Dramas, TV Sci-Fi &...
# description       In a future where the elite inhabit an island ...
# Name: 85855, dtype: object

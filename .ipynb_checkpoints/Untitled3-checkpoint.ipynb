# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import pairwise_distances, pairwise_distances_chunked
from scipy.sparse import vstack
from nltk.corpus.reader.wordnet import NOUN
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
imdb_movies = pd.read_csv("data/IMDb movies.csv", low_memory=False)

# %%
netflix = pd.read_csv("data/netflix_titles.csv")

# %%
imdb_recomend = imdb_movies[["original_title", "year", "genre","director", "actors", "description"]]

# %%
def remove_spaces(lst):
    spaces_removed = []
    for name in lst:
        spaces_removed.append(name.replace(" ", ""))
    return spaces_removed

# %%
def list_for_remove(string):
    string=str(string)
    return " ".join(remove_spaces(string.split(", ")))

# %%
def clean_up(imdb_recomend):
    #fill any NAN values
    imdb_recomend=imdb_recomend.copy()
    imdb_recomend.director.fillna("Unlisted",inplace=True)
    imdb_recomend.actors.fillna("Unavailable",inplace=True)
    imdb_recomend.genre.fillna("Unknown",inplace=True)  
    
    #remove spaces from actors and directors names
    imdb_recomend["actors"] = imdb_recomend["actors"].apply(lambda x: list_for_remove(x))
    imdb_recomend["director"] = imdb_recomend["director"].apply(lambda x: list_for_remove(x))
    imdb_recomend["genre"] = imdb_recomend["genre"].apply(lambda x: list_for_remove(x))
#     imdb_recomend["original_title"] = imdb_recomend["original_title"].apply(lambda x: list_for_remove(x))

    return imdb_recomend

# %%
imdb_recomend = clean_up(imdb_recomend)

# %%
def get_keywords(imdb_recomend):
    imdb_recomend =imdb_recomend.copy()
    imdb_recomend.description.fillna("Unknown",inplace=True) 
    imdb_recomend.description = imdb_recomend.description.apply(lambda x: make_keywords(x))
    imdb_recomend.original_title = imdb_recomend.original_title.apply(lambda x: make_keywords(x))
    return imdb_recomend

# %%
def make_keywords(string):
    tokens = word_tokenize(string)
    # convert to lower case
    tokens = [w.lower() for w in tokens]
    # remove punctuation from each word
    import string
    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    words = [word for word in stripped if word.isalpha()]
    # filter out stop words
    from nltk.corpus import stopwords
    stop_words = set(stopwords.words(['arabic', 'azerbaijani', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek','hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']))
    words = [w for w in words if not w in stop_words]
    lem = WordNetLemmatizer()
    words = [lem.lemmatize(w) for w in words]
    return " ".join(words)

# %%
imdb_recomend = get_keywords(imdb_recomend)

# %%
imdb_recomend
# Out:
#                   original_title  year                    genre  \
# 0                     miss jerry  1894                  Romance
# 1               story kelly gang  1906    Biography Crime Drama
# 2                     sorte drøm  1911                    Drama
# 3                      cleopatra  1912            Drama History
# 4                       linferno  1911  Adventure Drama Fantasy
# ...                          ...   ...                      ...
# 85850                       lion  2020                   Comedy
# 85851     beentjes sinthildegard  2020             Comedy Drama
# 85852  padmavyuhathile abhimanyu  2019                    Drama
# 85853          sokagin çocuklari  2019             Drama Family
# 85854            vida sense sara  2019                    Drama
#
#                                director  \
# 0                        AlexanderBlack
# 1                           CharlesTait
# 2                              UrbanGad
# 3                      CharlesL.Gaskill
# 4      FrancescoBertolini AdolfoPadovan
# ...                                 ...
# 85850             LudovicColbeau-Justin
# 85851                    JohanNijenhuis
# 85852                    VineeshAaradya
# 85853                   AhmetFaikAkinci
# 85854                          LauraJou
#
#                                                   actors  \
# 0          BlancheBayliss WilliamCourtenay ChaunceyDepew
# 1      ElizabethTait JohnTait NormanCampbell BellaCol...
# 2      AstaNielsen ValdemarPsilander GunnarHelsengree...
# 3      HelenGardner PearlSindelar MissFielding MissRo...
# 4      SalvatorePapa ArturoPirovano GiuseppedeLiguoro...
# ...                                                  ...
# 85850  DanyBoon PhilippeKaterine AnneSerra SamuelJouy...
# 85851  HermanFinkers JohannaterSteege LeonieterBraak ...
# 85852  AnoopChandran Indrans SonaNair SimonBrittoRodr...
# 85853  AhmetFaikAkinci BelmaMamati MetinKeçeci Burhan...
# 85854  MariaMoreraColomer BielRossellPelfort IsaacAlc...
#
#                                              description
# 0                              adventure female reporter
# 1           true story notorious australian outlaw kelly
# 2      two high rank wooing beautiful famous equestri...
# 3      fabled queen egypt affair roman general marc a...
# 4      loosely adapted dante divine comedy inspired i...
# ...                                                  ...
# 85850  psychiatric hospital patient pretend crazy cha...
# 85851  middleaged veterinary surgeon belief wife pamp...
# 85852                                            unknown
# 85853                                            unknown
# 85854  pep boy love girl grandparent village sara sum...
#
# [85855 rows x 6 columns]

# %%
first_five = imdb_recomend[:5].copy()

# %%
first_six = first_five.append(imdb_recomend[:1]).copy()

# %%
first_six
# Out:
#      original_title  year                    genre  \
# 0        miss jerry  1894                  Romance
# 1  story kelly gang  1906    Biography Crime Drama
# 2        sorte drøm  1911                    Drama
# 3         cleopatra  1912            Drama History
# 4          linferno  1911  Adventure Drama Fantasy
# 0        miss jerry  1894                  Romance
#
#                            director  \
# 0                    AlexanderBlack
# 1                       CharlesTait
# 2                          UrbanGad
# 3                  CharlesL.Gaskill
# 4  FrancescoBertolini AdolfoPadovan
# 0                    AlexanderBlack
#
#                                               actors  \
# 0      BlancheBayliss WilliamCourtenay ChaunceyDepew
# 1  ElizabethTait JohnTait NormanCampbell BellaCol...
# 2  AstaNielsen ValdemarPsilander GunnarHelsengree...
# 3  HelenGardner PearlSindelar MissFielding MissRo...
# 4  SalvatorePapa ArturoPirovano GiuseppedeLiguoro...
# 0      BlancheBayliss WilliamCourtenay ChaunceyDepew
#
#                                          description
# 0                          adventure female reporter
# 1       true story notorious australian outlaw kelly
# 2  two high rank wooing beautiful famous equestri...
# 3  fabled queen egypt affair roman general marc a...
# 4  loosely adapted dante divine comedy inspired i...
# 0                          adventure female reporter

# %%
def mashup(imdb):
    str_list = []
    for i in range(imdb.shape[0]):
        if i not in imdb.index:
            continue
        key = imdb.description.iloc[i]+" "+imdb.year.iloc[i]+" "+imdb.actors.iloc[i]+" "+imdb.actors.iloc[i]+" "+imdb.actors.iloc[i]+" "+imdb.actors.iloc[i]+" "+imdb.actors.iloc[i]+" "+imdb.director.iloc[i]+" "+imdb.director.iloc[i]+" "+imdb.director.iloc[i]+" "+imdb.genre.iloc[i]+" "+imdb.original_title.iloc[i]+" "+imdb.original_title.iloc[i]
        str_list.append(key)
        print(key)
        print()
    return str_list

# %%
imdb_lst = mashup(first_six)
# Out:
# adventure female reporter 1894 BlancheBayliss WilliamCourtenay ChaunceyDepew BlancheBayliss WilliamCourtenay ChaunceyDepew BlancheBayliss WilliamCourtenay ChaunceyDepew BlancheBayliss WilliamCourtenay ChaunceyDepew BlancheBayliss WilliamCourtenay ChaunceyDepew AlexanderBlack AlexanderBlack AlexanderBlack Romance miss jerry miss jerry
#
# true story notorious australian outlaw kelly 1906 ElizabethTait JohnTait NormanCampbell BellaCola WillCoyne SamCrewes JackEnnis JohnForde VeraLinden Mr.Marshall Mr.McKenzie FrankMills OllieWilson ElizabethTait JohnTait NormanCampbell BellaCola WillCoyne SamCrewes JackEnnis JohnForde VeraLinden Mr.Marshall Mr.McKenzie FrankMills OllieWilson ElizabethTait JohnTait NormanCampbell BellaCola WillCoyne SamCrewes JackEnnis JohnForde VeraLinden Mr.Marshall Mr.McKenzie FrankMills OllieWilson ElizabethTait JohnTait NormanCampbell BellaCola WillCoyne SamCrewes JackEnnis JohnForde VeraLinden Mr.Marshall Mr.McKenzie FrankMills OllieWilson ElizabethTait JohnTait NormanCampbell BellaCola WillCoyne SamCrewes JackEnnis JohnForde VeraLinden Mr.Marshall Mr.McKenzie FrankMills OllieWilson CharlesTait CharlesTait CharlesTait Biography Crime Drama story kelly gang story kelly gang
#
# two high rank wooing beautiful famous equestrian acrobat stella stella ignores jeweler hirsch accepts count waldberg offer follow home 1911 AstaNielsen ValdemarPsilander GunnarHelsengreen EmilAlbes HugoFlink MaryHagen AstaNielsen ValdemarPsilander GunnarHelsengreen EmilAlbes HugoFlink MaryHagen AstaNielsen ValdemarPsilander GunnarHelsengreen EmilAlbes HugoFlink MaryHagen AstaNielsen ValdemarPsilander GunnarHelsengreen EmilAlbes HugoFlink MaryHagen AstaNielsen ValdemarPsilander GunnarHelsengreen EmilAlbes HugoFlink MaryHagen UrbanGad UrbanGad UrbanGad Drama sorte drøm sorte drøm
#
# fabled queen egypt affair roman general marc antony ultimately disastrous 1912 HelenGardner PearlSindelar MissFielding MissRobson HeleneCostello CharlesSindelar Mr.Howard JamesR.Waite Mr.Osborne HarryKnowles Mr.Paul Mr.Brady Mr.Corker HelenGardner PearlSindelar MissFielding MissRobson HeleneCostello CharlesSindelar Mr.Howard JamesR.Waite Mr.Osborne HarryKnowles Mr.Paul Mr.Brady Mr.Corker HelenGardner PearlSindelar MissFielding MissRobson HeleneCostello CharlesSindelar Mr.Howard JamesR.Waite Mr.Osborne HarryKnowles Mr.Paul Mr.Brady Mr.Corker HelenGardner PearlSindelar MissFielding MissRobson HeleneCostello CharlesSindelar Mr.Howard JamesR.Waite Mr.Osborne HarryKnowles Mr.Paul Mr.Brady Mr.Corker HelenGardner PearlSindelar MissFielding MissRobson HeleneCostello CharlesSindelar Mr.Howard JamesR.Waite Mr.Osborne HarryKnowles Mr.Paul Mr.Brady Mr.Corker CharlesL.Gaskill CharlesL.Gaskill CharlesL.Gaskill Drama History cleopatra cleopatra
#
# loosely adapted dante divine comedy inspired illustration gustav doré original silent film restored new score tangerine dream 1911 SalvatorePapa ArturoPirovano GiuseppedeLiguoro PierDelleVigne AugustoMilla AttilioMotta EmiliseBeretta SalvatorePapa ArturoPirovano GiuseppedeLiguoro PierDelleVigne AugustoMilla AttilioMotta EmiliseBeretta SalvatorePapa ArturoPirovano GiuseppedeLiguoro PierDelleVigne AugustoMilla AttilioMotta EmiliseBeretta SalvatorePapa ArturoPirovano GiuseppedeLiguoro PierDelleVigne AugustoMilla AttilioMotta EmiliseBeretta SalvatorePapa ArturoPirovano GiuseppedeLiguoro PierDelleVigne AugustoMilla AttilioMotta EmiliseBeretta FrancescoBertolini AdolfoPadovan FrancescoBertolini AdolfoPadovan FrancescoBertolini AdolfoPadovan Adventure Drama Fantasy linferno linferno

# %%
for val in imdb_lst:
    print(val)
    print()
# Out:
# adventure female reporter 1894 BlancheBayliss WilliamCourtenay ChaunceyDepew BlancheBayliss WilliamCourtenay ChaunceyDepew BlancheBayliss WilliamCourtenay ChaunceyDepew BlancheBayliss WilliamCourtenay ChaunceyDepew BlancheBayliss WilliamCourtenay ChaunceyDepew AlexanderBlack AlexanderBlack AlexanderBlack Romance miss jerry miss jerry
#
# true story notorious australian outlaw kelly 1906 ElizabethTait JohnTait NormanCampbell BellaCola WillCoyne SamCrewes JackEnnis JohnForde VeraLinden Mr.Marshall Mr.McKenzie FrankMills OllieWilson ElizabethTait JohnTait NormanCampbell BellaCola WillCoyne SamCrewes JackEnnis JohnForde VeraLinden Mr.Marshall Mr.McKenzie FrankMills OllieWilson ElizabethTait JohnTait NormanCampbell BellaCola WillCoyne SamCrewes JackEnnis JohnForde VeraLinden Mr.Marshall Mr.McKenzie FrankMills OllieWilson ElizabethTait JohnTait NormanCampbell BellaCola WillCoyne SamCrewes JackEnnis JohnForde VeraLinden Mr.Marshall Mr.McKenzie FrankMills OllieWilson ElizabethTait JohnTait NormanCampbell BellaCola WillCoyne SamCrewes JackEnnis JohnForde VeraLinden Mr.Marshall Mr.McKenzie FrankMills OllieWilson CharlesTait CharlesTait CharlesTait Biography Crime Drama story kelly gang story kelly gang
#
# two high rank wooing beautiful famous equestrian acrobat stella stella ignores jeweler hirsch accepts count waldberg offer follow home 1911 AstaNielsen ValdemarPsilander GunnarHelsengreen EmilAlbes HugoFlink MaryHagen AstaNielsen ValdemarPsilander GunnarHelsengreen EmilAlbes HugoFlink MaryHagen AstaNielsen ValdemarPsilander GunnarHelsengreen EmilAlbes HugoFlink MaryHagen AstaNielsen ValdemarPsilander GunnarHelsengreen EmilAlbes HugoFlink MaryHagen AstaNielsen ValdemarPsilander GunnarHelsengreen EmilAlbes HugoFlink MaryHagen UrbanGad UrbanGad UrbanGad Drama sorte drøm sorte drøm
#
# fabled queen egypt affair roman general marc antony ultimately disastrous 1912 HelenGardner PearlSindelar MissFielding MissRobson HeleneCostello CharlesSindelar Mr.Howard JamesR.Waite Mr.Osborne HarryKnowles Mr.Paul Mr.Brady Mr.Corker HelenGardner PearlSindelar MissFielding MissRobson HeleneCostello CharlesSindelar Mr.Howard JamesR.Waite Mr.Osborne HarryKnowles Mr.Paul Mr.Brady Mr.Corker HelenGardner PearlSindelar MissFielding MissRobson HeleneCostello CharlesSindelar Mr.Howard JamesR.Waite Mr.Osborne HarryKnowles Mr.Paul Mr.Brady Mr.Corker HelenGardner PearlSindelar MissFielding MissRobson HeleneCostello CharlesSindelar Mr.Howard JamesR.Waite Mr.Osborne HarryKnowles Mr.Paul Mr.Brady Mr.Corker HelenGardner PearlSindelar MissFielding MissRobson HeleneCostello CharlesSindelar Mr.Howard JamesR.Waite Mr.Osborne HarryKnowles Mr.Paul Mr.Brady Mr.Corker CharlesL.Gaskill CharlesL.Gaskill CharlesL.Gaskill Drama History cleopatra cleopatra
#
# loosely adapted dante divine comedy inspired illustration gustav doré original silent film restored new score tangerine dream 1911 SalvatorePapa ArturoPirovano GiuseppedeLiguoro PierDelleVigne AugustoMilla AttilioMotta EmiliseBeretta SalvatorePapa ArturoPirovano GiuseppedeLiguoro PierDelleVigne AugustoMilla AttilioMotta EmiliseBeretta SalvatorePapa ArturoPirovano GiuseppedeLiguoro PierDelleVigne AugustoMilla AttilioMotta EmiliseBeretta SalvatorePapa ArturoPirovano GiuseppedeLiguoro PierDelleVigne AugustoMilla AttilioMotta EmiliseBeretta SalvatorePapa ArturoPirovano GiuseppedeLiguoro PierDelleVigne AugustoMilla AttilioMotta EmiliseBeretta FrancescoBertolini AdolfoPadovan FrancescoBertolini AdolfoPadovan FrancescoBertolini AdolfoPadovan Adventure Drama Fantasy linferno linferno
#
# adventure female reporter 1894 BlancheBayliss WilliamCourtenay ChaunceyDepew BlancheBayliss WilliamCourtenay ChaunceyDepew BlancheBayliss WilliamCourtenay ChaunceyDepew BlancheBayliss WilliamCourtenay ChaunceyDepew BlancheBayliss WilliamCourtenay ChaunceyDepew AlexanderBlack AlexanderBlack AlexanderBlack Romance miss jerry miss jerry

# %%
miss = imdb_lst[0]

# %%
imdb_lst.append(miss)

# %%
ivectorizor = CountVectorizer()
ikeys = ivectorizor.fit_transform(imdb_lst)

# %%
idist = pairwise_distances_chunked(ikeys, metric='cosine')

# %%
y=0
while (y < first_six.shape[0]):
    pull = next(idist)
    y += pull.shape[0]
    dbfile = open(f'chunks/tiny_imdb_test{y}.pkl', 'ab')
    # source, destination
    pickle.dump(pull, dbfile)                     
    dbfile.close()

# %%
pull
# Out:
# array([[0.        , 1.        , 1.        , 1.        , 0.99312321,
#         0.        ],
#        [1.        , 0.        , 0.99663206, 0.63334801, 0.99685578,
#         1.        ],
#        [1.        , 0.99663206, 0.        , 0.99771723, 0.99017291,
#         1.        ],
#        [1.        , 0.63334801, 0.99771723, 0.        , 0.99786886,
#         1.        ],
#        [0.99312321, 0.99685578, 0.99017291, 0.99786886, 0.        ,
#         0.99312321],
#        [0.        , 1.        , 1.        , 1.        , 0.99312321,
#         0.        ]])

# %%
print(pull.shape[0])
studs = np.argsort(pull[0])
first_six['original_title'][studs]
# Out:
# 6
# 0          miss jerry
# 5          miss jerry
# 4            linferno
# 1    story kelly gang
# 2          sorte drøm
# 3           cleopatra
# Name: original_title, dtype: object

# %%
pull[0]
# Out:
# array([0.        , 1.        , 1.        , 1.        , 0.99312321])

# %%
pull[4]
# Out:
# array([0.99312321, 0.99685578, 0.99017291, 0.99786886, 0.        ])

# %%
sim = 1-pull

# %%
sim[0]
# Out:
# array([1.        , 0.        , 0.        , 0.        , 0.00687679,
#        1.        ])

# %%
sim[5]
# Out:
# array([1.        , 0.        , 0.        , 0.        , 0.00687679,
#        1.        ])

# %%
studs = np.argsort(sim[0])[::-1]
first_six.original_title[studs]
# Out:
# 5          miss jerry
# 0          miss jerry
# 4            linferno
# 3           cleopatra
# 2          sorte drøm
# 1    story kelly gang
# Name: original_title, dtype: object

# %%
first_six = first_six.reset_index()

# %%
first_six
# Out:
#    index    original_title  year                    genre  \
# 0      0        miss jerry  1894                  Romance
# 1      1  story kelly gang  1906    Biography Crime Drama
# 2      2        sorte drøm  1911                    Drama
# 3      3         cleopatra  1912            Drama History
# 4      4          linferno  1911  Adventure Drama Fantasy
# 5      0        miss jerry  1894                  Romance
#
#                            director  \
# 0                    AlexanderBlack
# 1                       CharlesTait
# 2                          UrbanGad
# 3                  CharlesL.Gaskill
# 4  FrancescoBertolini AdolfoPadovan
# 5                    AlexanderBlack
#
#                                               actors  \
# 0      BlancheBayliss WilliamCourtenay ChaunceyDepew
# 1  ElizabethTait JohnTait NormanCampbell BellaCol...
# 2  AstaNielsen ValdemarPsilander GunnarHelsengree...
# 3  HelenGardner PearlSindelar MissFielding MissRo...
# 4  SalvatorePapa ArturoPirovano GiuseppedeLiguoro...
# 5      BlancheBayliss WilliamCourtenay ChaunceyDepew
#
#                                          description
# 0                          adventure female reporter
# 1       true story notorious australian outlaw kelly
# 2  two high rank wooing beautiful famous equestri...
# 3  fabled queen egypt affair roman general marc a...
# 4  loosely adapted dante divine comedy inspired i...
# 5                          adventure female reporter

# %%
netflix.rename(columns = {'show_id': 'title_id', 'title': 'original_title','release_year': 'year', 'listed_in': 'genre','cast': 'actors' },inplace=True)

# %%
netflix
# Out:
#      title_id     type                           original_title  \
# 0          s1  TV Show                                       3%
# 1          s2    Movie                                     7:19
# 2          s3    Movie                                    23:59
# 3          s4    Movie                                        9
# 4          s5    Movie                                       21
# ...       ...      ...                                      ...
# 7782    s7783    Movie                                     Zozo
# 7783    s7784    Movie                                   Zubaan
# 7784    s7785    Movie                        Zulu Man in Japan
# 7785    s7786  TV Show                    Zumbo's Just Desserts
# 7786    s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                             actors  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                NaN                                            Nasty C
# 7785                NaN                         Adriano Zumbo, Rachel Khoo
# 7786           Sam Dunn                                                NaN
#
#                                                 country          date_added  \
# 0                                                Brazil     August 14, 2020
# 1                                                Mexico   December 23, 2016
# 2                                             Singapore   December 20, 2018
# 3                                         United States   November 16, 2017
# 4                                         United States     January 1, 2020
# ...                                                 ...                 ...
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7783                                              India       March 2, 2019
# 7784                                                NaN  September 25, 2020
# 7785                                          Australia    October 31, 2020
# 7786              United Kingdom, Canada, United States       March 1, 2020
#
#       year rating   duration  \
# 0     2020  TV-MA  4 Seasons
# 1     2016  TV-MA     93 min
# 2     2011      R     78 min
# 3     2009  PG-13     80 min
# 4     2008  PG-13    123 min
# ...    ...    ...        ...
# 7782  2005  TV-MA     99 min
# 7783  2015  TV-14    111 min
# 7784  2019  TV-MA     44 min
# 7785  2019  TV-PG   1 Season
# 7786  2019  TV-MA     90 min
#
#                                                   genre  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...
#
# [7787 rows x 12 columns]

# %%
imdb_movies['type']='Movie'

# %%
imdb_movies.rename(columns = {'imdb_title_id': 'title_id'},inplace=True)

# %%
imdb_cutdown = imdb_movies[['title_id','type','original_title','director','actors','year','duration','genre','description']].copy()

# %%
netflix_cutdown = netflix[['title_id','type','original_title','director','actors','year','duration','genre','description']].copy()

# %%
netflix_cutdown
# Out:
#      title_id     type                           original_title  \
# 0          s1  TV Show                                       3%
# 1          s2    Movie                                     7:19
# 2          s3    Movie                                    23:59
# 3          s4    Movie                                        9
# 4          s5    Movie                                       21
# ...       ...      ...                                      ...
# 7782    s7783    Movie                                     Zozo
# 7783    s7784    Movie                                   Zubaan
# 7784    s7785    Movie                        Zulu Man in Japan
# 7785    s7786  TV Show                    Zumbo's Just Desserts
# 7786    s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                             actors  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                NaN                                            Nasty C
# 7785                NaN                         Adriano Zumbo, Rachel Khoo
# 7786           Sam Dunn                                                NaN
#
#       year   duration                                              genre  \
# 0     2020  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     2016     93 min                       Dramas, International Movies
# 2     2011     78 min                Horror Movies, International Movies
# 3     2009     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4     2008    123 min                                             Dramas
# ...    ...        ...                                                ...
# 7782  2005     99 min                       Dramas, International Movies
# 7783  2015    111 min     Dramas, International Movies, Music & Musicals
# 7784  2019     44 min  Documentaries, International Movies, Music & M...
# 7785  2019   1 Season                 International TV Shows, Reality TV
# 7786  2019     90 min                    Documentaries, Music & Musicals
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...
#
# [7787 rows x 9 columns]

# %%
total_list = imdb_cutdown.copy()

# %%
total_list.append()
# Out:
#         title_id   type                  original_title  \
# 0      tt0000009  Movie                      Miss Jerry
# 1      tt0000574  Movie     The Story of the Kelly Gang
# 2      tt0001892  Movie                  Den sorte drøm
# 3      tt0002101  Movie                       Cleopatra
# 4      tt0002130  Movie                       L'Inferno
# ...          ...    ...                             ...
# 85850  tt9908390  Movie                         Le lion
# 85851  tt9911196  Movie  De Beentjes van Sint-Hildegard
# 85852  tt9911774  Movie       Padmavyuhathile Abhimanyu
# 85853  tt9914286  Movie               Sokagin Çocuklari
# 85854  tt9914942  Movie      La vida sense la Sara Amat
#
#                                   director  \
# 0                          Alexander Black
# 1                             Charles Tait
# 2                                Urban Gad
# 3                       Charles L. Gaskill
# 4      Francesco Bertolini, Adolfo Padovan
# ...                                    ...
# 85850               Ludovic Colbeau-Justin
# 85851                      Johan Nijenhuis
# 85852                      Vineesh Aaradya
# 85853                    Ahmet Faik Akinci
# 85854                            Laura Jou
#
#                                                   actors  year  duration  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...  1894        45
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...  1906        70
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...  1911        53
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...  1912       100
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...  1911        68
# ...                                                  ...   ...       ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...  2020        95
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...  2020       103
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...  2019       130
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...  2019        98
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...  2019        74
#
#                            genre  \
# 0                        Romance
# 1        Biography, Crime, Drama
# 2                          Drama
# 3                 Drama, History
# 4      Adventure, Drama, Fantasy
# ...                          ...
# 85850                     Comedy
# 85851              Comedy, Drama
# 85852                      Drama
# 85853              Drama, Family
# 85854                      Drama
#
#                                              description
# 0      The adventures of a female reporter in the 1890s.
# 1      True story of notorious Australian outlaw Ned ...
# 2      Two men of high rank are both wooing the beaut...
# 3      The fabled queen of Egypt's affair with Roman ...
# 4      Loosely adapted from Dante's Divine Comedy and...
# ...                                                  ...
# 85850  A psychiatric hospital patient pretends to be ...
# 85851  A middle-aged veterinary surgeon believes his ...
# 85852                                                NaN
# 85853                                                NaN
# 85854  Pep, a 13-year-old boy, is in love with a girl...
#
# [85855 rows x 9 columns]

# %%
for i in range(netflix_cutdown.shape[0]):
    total_list=total_list.append(netflix_cutdown.iloc[i])

# %%
netflix_cutdown.shape
# Out:
# (7787, 9)

# %%
type(netflix_cutdown.iloc[0])
# Out:
# pandas.core.series.Series

# %%
total_list
# Out:
#        title_id     type                           original_title  \
# 0     tt0000009    Movie                               Miss Jerry
# 1     tt0000574    Movie              The Story of the Kelly Gang
# 2     tt0001892    Movie                           Den sorte drøm
# 3     tt0002101    Movie                                Cleopatra
# 4     tt0002130    Movie                                L'Inferno
# ...         ...      ...                                      ...
# 7782      s7783    Movie                                     Zozo
# 7783      s7784    Movie                                   Zubaan
# 7784      s7785    Movie                        Zulu Man in Japan
# 7785      s7786  TV Show                    Zumbo's Just Desserts
# 7786      s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                  director  \
# 0                         Alexander Black
# 1                            Charles Tait
# 2                               Urban Gad
# 3                      Charles L. Gaskill
# 4     Francesco Bertolini, Adolfo Padovan
# ...                                   ...
# 7782                          Josef Fares
# 7783                          Mozez Singh
# 7784                                  NaN
# 7785                                  NaN
# 7786                             Sam Dunn
#
#                                                  actors  year  duration  \
# 0     Blanche Bayliss, William Courtenay, Chauncey D...  1894        45
# 1     Elizabeth Tait, John Tait, Norman Campbell, Be...  1906        70
# 2     Asta Nielsen, Valdemar Psilander, Gunnar Helse...  1911        53
# 3     Helen Gardner, Pearl Sindelar, Miss Fielding, ...  1912       100
# 4     Salvatore Papa, Arturo Pirovano, Giuseppe de L...  1911        68
# ...                                                 ...   ...       ...
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...  2005    99 min
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...  2015   111 min
# 7784                                            Nasty C  2019    44 min
# 7785                         Adriano Zumbo, Rachel Khoo  2019  1 Season
# 7786                                                NaN  2019    90 min
#
#                                                   genre  \
# 0                                               Romance
# 1                               Biography, Crime, Drama
# 2                                                 Drama
# 3                                        Drama, History
# 4                             Adventure, Drama, Fantasy
# ...                                                 ...
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 0     The adventures of a female reporter in the 1890s.
# 1     True story of notorious Australian outlaw Ned ...
# 2     Two men of high rank are both wooing the beaut...
# 3     The fabled queen of Egypt's affair with Roman ...
# 4     Loosely adapted from Dante's Divine Comedy and...
# ...                                                 ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...
#
# [93642 rows x 9 columns]

# %%
total_list = total_list.reset_index()

# %%
total_list.drop('index',inplace=True, axis=1)

# %%
total_list
# Out:
#         title_id     type                           original_title  \
# 0      tt0000009    Movie                               Miss Jerry
# 1      tt0000574    Movie              The Story of the Kelly Gang
# 2      tt0001892    Movie                           Den sorte drøm
# 3      tt0002101    Movie                                Cleopatra
# 4      tt0002130    Movie                                L'Inferno
# ...          ...      ...                                      ...
# 93637      s7783    Movie                                     Zozo
# 93638      s7784    Movie                                   Zubaan
# 93639      s7785    Movie                        Zulu Man in Japan
# 93640      s7786  TV Show                    Zumbo's Just Desserts
# 93641      s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                   director  \
# 0                          Alexander Black
# 1                             Charles Tait
# 2                                Urban Gad
# 3                       Charles L. Gaskill
# 4      Francesco Bertolini, Adolfo Padovan
# ...                                    ...
# 93637                          Josef Fares
# 93638                          Mozez Singh
# 93639                                  NaN
# 93640                                  NaN
# 93641                             Sam Dunn
#
#                                                   actors  year  duration  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...  1894        45
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...  1906        70
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...  1911        53
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...  1912       100
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...  1911        68
# ...                                                  ...   ...       ...
# 93637  Imad Creidi, Antoinette Turk, Elias Gergi, Car...  2005    99 min
# 93638  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...  2015   111 min
# 93639                                            Nasty C  2019    44 min
# 93640                         Adriano Zumbo, Rachel Khoo  2019  1 Season
# 93641                                                NaN  2019    90 min
#
#                                                    genre  \
# 0                                                Romance
# 1                                Biography, Crime, Drama
# 2                                                  Drama
# 3                                         Drama, History
# 4                              Adventure, Drama, Fantasy
# ...                                                  ...
# 93637                       Dramas, International Movies
# 93638     Dramas, International Movies, Music & Musicals
# 93639  Documentaries, International Movies, Music & M...
# 93640                 International TV Shows, Reality TV
# 93641                    Documentaries, Music & Musicals
#
#                                              description
# 0      The adventures of a female reporter in the 1890s.
# 1      True story of notorious Australian outlaw Ned ...
# 2      Two men of high rank are both wooing the beaut...
# 3      The fabled queen of Egypt's affair with Roman ...
# 4      Loosely adapted from Dante's Divine Comedy and...
# ...                                                  ...
# 93637  When Lebanon's Civil War deprives Zozo of his ...
# 93638  A scrappy but poor boy worms his way into a ty...
# 93639  In this documentary, South African rapper Nast...
# 93640  Dessert wizard Adriano Zumbo looks for the nex...
# 93641  This documentary delves into the mystique behi...
#
# [93642 rows x 9 columns]

# %%
type(total_list[total_list.type=='Movie'].duration[93639])
# Out:
# int

# %%
def strip_min(x):
    if isinstance(x, str):
        lst = x.split()
        if len(lst)==1:
            x = int(lst[0])
        else:
            if lst[1]=='min':
                x = lst[0]
    return x

# %%
total_list.duration = total_list.duration.apply(lambda x: strip_min(x))

# %%
total_list
# Out:
#         title_id     type                           original_title  \
# 0      tt0000009    Movie                               Miss Jerry
# 1      tt0000574    Movie              The Story of the Kelly Gang
# 2      tt0001892    Movie                           Den sorte drøm
# 3      tt0002101    Movie                                Cleopatra
# 4      tt0002130    Movie                                L'Inferno
# ...          ...      ...                                      ...
# 93637      s7783    Movie                                     Zozo
# 93638      s7784    Movie                                   Zubaan
# 93639      s7785    Movie                        Zulu Man in Japan
# 93640      s7786  TV Show                    Zumbo's Just Desserts
# 93641      s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                   director  \
# 0                          Alexander Black
# 1                             Charles Tait
# 2                                Urban Gad
# 3                       Charles L. Gaskill
# 4      Francesco Bertolini, Adolfo Padovan
# ...                                    ...
# 93637                          Josef Fares
# 93638                          Mozez Singh
# 93639                                  NaN
# 93640                                  NaN
# 93641                             Sam Dunn
#
#                                                   actors  year  duration  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...  1894        45
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...  1906        70
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...  1911        53
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...  1912       100
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...  1911        68
# ...                                                  ...   ...       ...
# 93637  Imad Creidi, Antoinette Turk, Elias Gergi, Car...  2005        99
# 93638  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...  2015       111
# 93639                                            Nasty C  2019        44
# 93640                         Adriano Zumbo, Rachel Khoo  2019  1 Season
# 93641                                                NaN  2019        90
#
#                                                    genre  \
# 0                                                Romance
# 1                                Biography, Crime, Drama
# 2                                                  Drama
# 3                                         Drama, History
# 4                              Adventure, Drama, Fantasy
# ...                                                  ...
# 93637                       Dramas, International Movies
# 93638     Dramas, International Movies, Music & Musicals
# 93639  Documentaries, International Movies, Music & M...
# 93640                 International TV Shows, Reality TV
# 93641                    Documentaries, Music & Musicals
#
#                                              description
# 0      The adventures of a female reporter in the 1890s.
# 1      True story of notorious Australian outlaw Ned ...
# 2      Two men of high rank are both wooing the beaut...
# 3      The fabled queen of Egypt's affair with Roman ...
# 4      Loosely adapted from Dante's Divine Comedy and...
# ...                                                  ...
# 93637  When Lebanon's Civil War deprives Zozo of his ...
# 93638  A scrappy but poor boy worms his way into a ty...
# 93639  In this documentary, South African rapper Nast...
# 93640  Dessert wizard Adriano Zumbo looks for the nex...
# 93641  This documentary delves into the mystique behi...
#
# [93642 rows x 9 columns]

# %%
total_list[total_list.type=='TV Show'].duration
# Out:
# 85855    4 Seasons
# 85860     1 Season
# 85866     1 Season
# 85867     1 Season
# 85871     1 Season
#            ...
# 93622     1 Season
# 93630     1 Season
# 93632    2 Seasons
# 93634     1 Season
# 93640     1 Season
# Name: duration, Length: 2410, dtype: object

# %%
total_list.to_csv("Combined_Netflix_IMDb_Useful_Columns.csv")

# %%
total_list.fillna("NAN",inplace=True)

# %%
total_list
# Out:
#         title_id     type                           original_title  \
# 0      tt0000009    Movie                               Miss Jerry
# 1      tt0000574    Movie              The Story of the Kelly Gang
# 2      tt0001892    Movie                           Den sorte drøm
# 3      tt0002101    Movie                                Cleopatra
# 4      tt0002130    Movie                                L'Inferno
# ...          ...      ...                                      ...
# 93637      s7783    Movie                                     Zozo
# 93638      s7784    Movie                                   Zubaan
# 93639      s7785    Movie                        Zulu Man in Japan
# 93640      s7786  TV Show                    Zumbo's Just Desserts
# 93641      s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                   director  \
# 0                          Alexander Black
# 1                             Charles Tait
# 2                                Urban Gad
# 3                       Charles L. Gaskill
# 4      Francesco Bertolini, Adolfo Padovan
# ...                                    ...
# 93637                          Josef Fares
# 93638                          Mozez Singh
# 93639                                  NAN
# 93640                                  NAN
# 93641                             Sam Dunn
#
#                                                   actors  year  duration  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...  1894        45
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...  1906        70
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...  1911        53
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...  1912       100
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...  1911        68
# ...                                                  ...   ...       ...
# 93637  Imad Creidi, Antoinette Turk, Elias Gergi, Car...  2005        99
# 93638  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...  2015       111
# 93639                                            Nasty C  2019        44
# 93640                         Adriano Zumbo, Rachel Khoo  2019  1 Season
# 93641                                                NAN  2019        90
#
#                                                    genre  \
# 0                                                Romance
# 1                                Biography, Crime, Drama
# 2                                                  Drama
# 3                                         Drama, History
# 4                              Adventure, Drama, Fantasy
# ...                                                  ...
# 93637                       Dramas, International Movies
# 93638     Dramas, International Movies, Music & Musicals
# 93639  Documentaries, International Movies, Music & M...
# 93640                 International TV Shows, Reality TV
# 93641                    Documentaries, Music & Musicals
#
#                                              description
# 0      The adventures of a female reporter in the 1890s.
# 1      True story of notorious Australian outlaw Ned ...
# 2      Two men of high rank are both wooing the beaut...
# 3      The fabled queen of Egypt's affair with Roman ...
# 4      Loosely adapted from Dante's Divine Comedy and...
# ...                                                  ...
# 93637  When Lebanon's Civil War deprives Zozo of his ...
# 93638  A scrappy but poor boy worms his way into a ty...
# 93639  In this documentary, South African rapper Nast...
# 93640  Dessert wizard Adriano Zumbo looks for the nex...
# 93641  This documentary delves into the mystique behi...
#
# [93642 rows x 9 columns]

# %%
total_list[total_list.genre=="NAN"]
# Out:
# Empty DataFrame
# Columns: [title_id, type, original_title, director, actors, year, duration, genre, description]
# Index: []

# %%
total_list
# Out:
#         title_id     type                           original_title  \
# 0      tt0000009    Movie                               Miss Jerry
# 1      tt0000574    Movie              The Story of the Kelly Gang
# 2      tt0001892    Movie                           Den sorte drøm
# 3      tt0002101    Movie                                Cleopatra
# 4      tt0002130    Movie                                L'Inferno
# ...          ...      ...                                      ...
# 93637      s7783    Movie                                     Zozo
# 93638      s7784    Movie                                   Zubaan
# 93639      s7785    Movie                        Zulu Man in Japan
# 93640      s7786  TV Show                    Zumbo's Just Desserts
# 93641      s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                   director  \
# 0                          Alexander Black
# 1                             Charles Tait
# 2                                Urban Gad
# 3                       Charles L. Gaskill
# 4      Francesco Bertolini, Adolfo Padovan
# ...                                    ...
# 93637                          Josef Fares
# 93638                          Mozez Singh
# 93639                                  NAN
# 93640                                  NAN
# 93641                             Sam Dunn
#
#                                                   actors  year  duration  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...  1894        45
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...  1906        70
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...  1911        53
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...  1912       100
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...  1911        68
# ...                                                  ...   ...       ...
# 93637  Imad Creidi, Antoinette Turk, Elias Gergi, Car...  2005        99
# 93638  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...  2015       111
# 93639                                            Nasty C  2019        44
# 93640                         Adriano Zumbo, Rachel Khoo  2019  1 Season
# 93641                                                NAN  2019        90
#
#                                                    genre  \
# 0                                                Romance
# 1                                Biography, Crime, Drama
# 2                                                  Drama
# 3                                         Drama, History
# 4                              Adventure, Drama, Fantasy
# ...                                                  ...
# 93637                       Dramas, International Movies
# 93638     Dramas, International Movies, Music & Musicals
# 93639  Documentaries, International Movies, Music & M...
# 93640                 International TV Shows, Reality TV
# 93641                    Documentaries, Music & Musicals
#
#                                              description
# 0      The adventures of a female reporter in the 1890s.
# 1      True story of notorious Australian outlaw Ned ...
# 2      Two men of high rank are both wooing the beaut...
# 3      The fabled queen of Egypt's affair with Roman ...
# 4      Loosely adapted from Dante's Divine Comedy and...
# ...                                                  ...
# 93637  When Lebanon's Civil War deprives Zozo of his ...
# 93638  A scrappy but poor boy worms his way into a ty...
# 93639  In this documentary, South African rapper Nast...
# 93640  Dessert wizard Adriano Zumbo looks for the nex...
# 93641  This documentary delves into the mystique behi...
#
# [93642 rows x 9 columns]
